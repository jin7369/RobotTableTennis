# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("trajectory_16.csv")

# %%
df.head()
# Out:
#      step     x         y    z
# 0  160000 -0.15  0.980000  0.5
# 1  160001 -0.15 -1.260760  0.5
# 2  160002 -0.15 -1.123420  0.5
# 3  160003 -0.15 -0.887980  0.5
# 4  160004 -0.15 -0.554441  0.5

# %%
plt.scatter(df['x'], df['z'])

# %%
len(df)
# Out:
# 10000
